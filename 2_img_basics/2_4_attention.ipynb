# %% [markdown]
# <a href="https://colab.research.google.com/github/karaage0703/python_image_recognition/blob/custom/2_img_basics/2_4_attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pythonで学ぶ画像認識　第2章 画像処理の基礎知識
# ## 第2.4節 注意機構を使った特徴抽出

# %% [markdown]
# ### モジュールのインポートと画像のダウンロード

# %%
from PIL import Image
import numpy as np

# %%
# !wget https://raw.githubusercontent.com/karaage0703/python_image_recognition/main/data/cosmos.jpg
# Out:
# --2023-03-25 14:34:43--  https://raw.githubusercontent.com/karaage0703/python_image_recognition/main/data/cosmos.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21468 (21K) [image/jpeg]
# Saving to: ‘cosmos.jpg’
#
# cosmos.jpg          100%[===================>]  20.96K  --.-KB/s    in 0.001s
#
# 2023-03-25 14:34:43 (24.6 MB/s) - ‘cosmos.jpg’ saved [21468/21468]

# %%
from PIL import Image
from matplotlib.pyplot import imshow

img = Image.open('cosmos.jpg')
imshow(img)

# %% [markdown]
# ###特徴空間への射影

# %%
# 画像の読み込み
img = Image.open('cosmos.jpg')

# NumPyを使うため画像をNumPy配列に変換
img = np.asarray(img, dtype='float32')

# 画像を特徴空間に射影
w = np.array([[ 0.0065, -0.0045, -0.0018,  0.0075,
                0.0095,  0.0075, -0.0026,  0.0022],
              [-0.0065,  0.0081,  0.0097, -0.0070,
               -0.0086, -0.0107,  0.0062, -0.0050],
              [ 0.0024, -0.0018,  0.0002,  0.0023,
                0.0017,  0.0021, -0.0017,  0.0016]])
features = np.matmul(img, w)

# %% [markdown]
# ###アテンションの計算

# %%
# アテンション計算用の特徴を画像から抽出
feature_white = features[50, 50]
feature_pink = features[200, 200]

# アテンションの計算
atten_white = np.matmul(features, feature_white)
atten_pink = np.matmul(features, feature_pink)

# ソフトマックスの計算
atten_white = np.exp(atten_white) / np.sum(np.exp(atten_white))
atten_pink = np.exp(atten_pink) / np.sum(np.exp(atten_pink))

# %% [markdown]
# ###注意の表示

# %%
# 表示用に最大・最小値で正規化
atten_white = (atten_white - np.amin(atten_white)) / \
    (np.amax(atten_white) - np.amin(atten_white))
atten_pink = (atten_pink - np.amin(atten_pink)) / \
    (np.amax(atten_pink) - np.amin(atten_pink))

# NumPy配列をPIL画像に変換
img_atten_white = Image.fromarray(
    (atten_white * 255).astype('uint8'))
img_atten_pink = Image.fromarray(
    (atten_pink * 255).astype('uint8'))

print('白のコスモスに対するアテンション')
display(img_atten_white)
print('ピンクのコスモスに対するアテンション')
display(img_atten_pink)
# Out:
# 白のコスモスに対するアテンション
# <PIL.Image.Image image mode=L size=256x256 at 0x7F15B853C8E0>
# ピンクのコスモスに対するアテンション
# <PIL.Image.Image image mode=L size=256x256 at 0x7F15C8A42250>
